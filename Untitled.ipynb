# %%
import pandas as pd
import numpy as np
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import requests
import json
import pickle
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.svm import LinearSVC
from sklearn.preprocessing import PolynomialFeatures
from graphviz import Source
import pydotplus
import os

# %%
hot = pd.read_csv('Hot Stuff.csv')

# %%
hot.head()
# Out:
#                                                  url     WeekID  \
# 0  http://www.billboard.com/charts/hot-100/1990-0...  2/10/1990
# 1  http://www.billboard.com/charts/hot-100/1990-0...  2/17/1990
# 2  http://www.billboard.com/charts/hot-100/1990-0...  2/24/1990
# 3  http://www.billboard.com/charts/hot-100/1990-0...   3/3/1990
# 4  http://www.billboard.com/charts/hot-100/1990-0...  3/10/1990
#
#    Week Position                      Song   Performer  \
# 0             75  Don't Wanna Fall In Love  Jane Child
# 1             53  Don't Wanna Fall In Love  Jane Child
# 2             43  Don't Wanna Fall In Love  Jane Child
# 3             37  Don't Wanna Fall In Love  Jane Child
# 4             27  Don't Wanna Fall In Love  Jane Child
#
#                                SongID  Instance  Previous Week Position  \
# 0  Don't Wanna Fall In LoveJane Child         1                     NaN
# 1  Don't Wanna Fall In LoveJane Child         1                    75.0
# 2  Don't Wanna Fall In LoveJane Child         1                    53.0
# 3  Don't Wanna Fall In LoveJane Child         1                    43.0
# 4  Don't Wanna Fall In LoveJane Child         1                    37.0
#
#    Peak Position  Weeks on Chart
# 0             75               1
# 1             53               2
# 2             43               3
# 3             37               4
# 4             27               5

# %%
hot_grouped = hot.groupby('SongID', as_index=False).agg({'Peak Position': 'min', 'Weeks on Chart': 'max'})

# %%
hot_grouped[hot_grouped['SongID']=='Gin And JuiceSnoop Doggy Dogg']
# Out:
#                              SongID  Peak Position  Weeks on Chart
# 7745  Gin And JuiceSnoop Doggy Dogg              8              20

# %%
df = pd.read_excel('Hot 100 Audio Features.xlsx')

# %%
df = df.merge(hot_grouped, on='SongID')

# %%
df=df.merge(hot[['SongID','Song', 'Performer']], on='SongID')

# %%
df.head()
# Out:
#                                      SongID        spotify_track_id  \
# 0  Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
# 1  Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
# 2  Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
# 3  Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
# 4  Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
#
#                                         artist_genre  \
# 0  ['brill building pop', 'classic girl group', '...
# 1  ['brill building pop', 'classic girl group', '...
# 2  ['brill building pop', 'classic girl group', '...
# 3  ['brill building pop', 'classic girl group', '...
# 4  ['brill building pop', 'classic girl group', '...
#
#    spotify_track_duration_ms  spotify_track_popularity  danceability  energy  \
# 0                   177973.0                      23.0          0.39   0.793
# 1                   177973.0                      23.0          0.39   0.793
# 2                   177973.0                      23.0          0.39   0.793
# 3                   177973.0                      23.0          0.39   0.793
# 4                   177973.0                      23.0          0.39   0.793
#
#    key  loudness  mode  ...  acousticness  instrumentalness  liveness  \
# 0  3.0    -8.887   1.0  ...         0.212           0.00511     0.175
# 1  3.0    -8.887   1.0  ...         0.212           0.00511     0.175
# 2  3.0    -8.887   1.0  ...         0.212           0.00511     0.175
# 3  3.0    -8.887   1.0  ...         0.212           0.00511     0.175
# 4  3.0    -8.887   1.0  ...         0.212           0.00511     0.175
#
#    valence    tempo  time_signature  Peak Position  Weeks on Chart  \
# 0    0.889  200.297             4.0             11              12
# 1    0.889  200.297             4.0             11              12
# 2    0.889  200.297             4.0             11              12
# 3    0.889  200.297             4.0             11              12
# 4    0.889  200.297             4.0             11              12
#
#           Song                      Performer
# 0  Honey Chile  Martha Reeves & The Vandellas
# 1  Honey Chile  Martha Reeves & The Vandellas
# 2  Honey Chile  Martha Reeves & The Vandellas
# 3  Honey Chile  Martha Reeves & The Vandellas
# 4  Honey Chile  Martha Reeves & The Vandellas
#
# [5 rows x 21 columns]

# %%
df.drop_duplicates('SongID', keep='first', inplace = True)

# %%
df.shape
# Out:
# (28078, 21)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (21732, 21)

# %%
df['billboard'] = 1

# %%
df.head()
# Out:
#                                                SongID        spotify_track_id  \
# 0            Honey ChileMartha Reeves & The Vandellas  3YGuismm9qnCaEfUkD8uQA
# 12                          Fire And RainJames Taylor  3LcYYV9ozePfgYYmXv0P3r
# 28                      Gin And JuiceSnoop Doggy Dogg  0WKYRFtH6KKbaNWjsxqm70
# 68  Hot Pants (She Got To Use What She Got To Get ...  6mwp3O2NelTb7WzB8QoFgh
# 79                    How Do I Make YouLinda Ronstadt  2WX2HSBKkcKVvqTukHZS22
#
#                                          artist_genre  \
# 0   ['brill building pop', 'classic girl group', '...
# 12  ['adult standards', 'folk', 'folk rock', 'folk...
# 28  ['g funk', 'gangster rap', 'hip hop', 'pop rap...
# 68                         ['funk', 'motown', 'soul']
# 79  ['adult standards', 'country rock', 'folk', 'f...
#
#     spotify_track_duration_ms  spotify_track_popularity  danceability  energy  \
# 0                    177973.0                      23.0         0.390   0.793
# 12                   200579.0                      74.0         0.611   0.350
# 28                   211493.0                      74.0         0.549   0.853
# 68                   189706.0                       7.0         0.835   0.740
# 79                   144773.0                      36.0         0.420   0.822
#
#      key  loudness  mode  ...  instrumentalness  liveness  valence    tempo  \
# 0    3.0    -8.887   1.0  ...          0.005110    0.1750    0.889  200.297
# 12   5.0   -14.480   1.0  ...          0.000008    0.0844    0.360   76.064
# 28   7.0    -4.293   1.0  ...          0.000296    0.6180    0.346   94.695
# 68  10.0    -6.514   0.0  ...          0.000000    0.0557    0.750   98.221
# 79  11.0    -8.269   1.0  ...          0.000038    0.1660    0.843  165.936
#
#     time_signature  Peak Position  Weeks on Chart  \
# 0              4.0             11              12
# 12             4.0              3              16
# 28             4.0              8              20
# 68             4.0             15              11
# 79             4.0             10              16
#
#                                                  Song  \
# 0                                         Honey Chile
# 12                                      Fire And Rain
# 28                                      Gin And Juice
# 68  Hot Pants (She Got To Use What She Got To Get ...
# 79                                  How Do I Make You
#
#                         Performer billboard
# 0   Martha Reeves & The Vandellas         1
# 12                   James Taylor         1
# 28               Snoop Doggy Dogg         1
# 68                    James Brown         1
# 79                 Linda Ronstadt         1
#
# [5 rows x 22 columns]

# %%
twok = pd.read_csv('tracks2.csv')

# %%
twok.head(2)
# Out:
#   artist_name release_date            track_name                track_id  \
# 0         TLC   1999-02-23             No Scrubs  1KGi9sZVMeszgZOWivFpxs
# 1   blink-182   1999-06-01  All The Small Things  2m1hi0nfMR9vdGC8UcrnwU
#
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0          81        0.0251         0.743       214400   0.675
# 1          80        0.0103         0.434       167067   0.897
#
#    instrumentalness  ...  liveness  loudness  mode  speechiness    tempo  \
# 0          0.000717  ...    0.0685    -4.267     0       0.0953   92.909
# 1          0.000000  ...    0.6120    -4.918     1       0.0488  148.726
#
#    time_signature  valence   Genres    subgenres popularity_artist
# 0               4    0.590  hip hop  atl hip hop                73
# 1               4    0.684     rock     pop punk                83
#
# [2 rows x 21 columns]

# %%
pickle_in = open("genres_full.pickle","rb")
genres_lst_full = pickle.load(pickle_in)

genres_df = pd.DataFrame(genres_lst_full)

genres_df.shape
# Out:
# (201707, 3)

# %%
twok = twok.merge(genres_df['genres'], left_index=True, right_index=True)
twok.head()
# Out:
#              artist_name release_date            track_name  \
# 0                    TLC   1999-02-23             No Scrubs
# 1              blink-182   1999-06-01  All The Small Things
# 2            Smash Mouth   1999-01-01              All Star
# 3        Destiny's Child   1999-07-27           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  ...  loudness  mode  speechiness  \
# 0       214400   0.675          0.000717  ...    -4.267     0       0.0953
# 1       167067   0.897          0.000000  ...    -4.918     1       0.0488
# 2       200373   0.861          0.000000  ...    -5.881     1       0.0323
# 3       271333   0.678          0.000000  ...    -3.525     0       0.1020
# 4       329733   0.767          0.001650  ...    -2.788     0       0.0270
#
#      tempo  time_signature  valence   Genres         subgenres  \
# 0   92.909               4    0.590  hip hop       atl hip hop
# 1  148.726               4    0.684     rock          pop punk
# 2  104.034               4    0.780     rock  alternative rock
# 3  138.009               4    0.734      pop         dance pop
# 4   96.483               4    0.328     rock  alternative rock
#
#   popularity_artist                                             genres
# 0                73  [atl hip hop, dance pop, girl group, hip hop, ...
# 1                83                   [pop punk, punk, socal pop punk]
# 2                71          [alternative rock, pop rock, post-grunge]
# 3                76  [dance pop, girl group, hip pop, pop, pop rap,...
# 4                86  [alternative rock, funk metal, funk rock, perm...
#
# [5 rows x 22 columns]

# %%
twok['SongID']= twok['track_name']+twok['artist_name']

# %%
twok.head()
# Out:
#              artist_name release_date            track_name  \
# 0                    TLC   1999-02-23             No Scrubs
# 1              blink-182   1999-06-01  All The Small Things
# 2            Smash Mouth   1999-01-01              All Star
# 3        Destiny's Child   1999-07-27           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  ...  mode  speechiness    tempo  \
# 0       214400   0.675          0.000717  ...     0       0.0953   92.909
# 1       167067   0.897          0.000000  ...     1       0.0488  148.726
# 2       200373   0.861          0.000000  ...     1       0.0323  104.034
# 3       271333   0.678          0.000000  ...     0       0.1020  138.009
# 4       329733   0.767          0.001650  ...     0       0.0270   96.483
#
#    time_signature  valence   Genres         subgenres  popularity_artist  \
# 0               4    0.590  hip hop       atl hip hop                 73
# 1               4    0.684     rock          pop punk                 83
# 2               4    0.780     rock  alternative rock                 71
# 3               4    0.734      pop         dance pop                 76
# 4               4    0.328     rock  alternative rock                 86
#
#                                               genres  \
# 0  [atl hip hop, dance pop, girl group, hip hop, ...
# 1                   [pop punk, punk, socal pop punk]
# 2          [alternative rock, pop rock, post-grunge]
# 3  [dance pop, girl group, hip pop, pop, pop rap,...
# 4  [alternative rock, funk metal, funk rock, perm...
#
#                                  SongID
# 0                          No ScrubsTLC
# 1         All The Small Thingsblink-182
# 2                   All StarSmash Mouth
# 3            Say My NameDestiny's Child
# 4  CalifornicationRed Hot Chili Peppers
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (21732, 22)

# %%
twok = twok[twok['popularity'] > 50]

# %%
twok.shape
# Out:
# (51880, 23)

# %%
top_songs = list(df['SongID'])

# %%
drop_df = twok[twok['SongID'].isin(top_songs)]

# %%
drop_df.head()
# Out:
#              artist_name release_date          track_name  \
# 0                    TLC   1999-02-23           No Scrubs
# 2            Smash Mouth   1999-01-01            All Star
# 3        Destiny's Child   1999-07-27         Say My Name
# 4  Red Hot Chili Peppers   1999-06-08     Californication
# 8                    Lit   1999-02-23  My Own Worst Enemy
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81       0.02510         0.743
# 2  3cfOd4CMv2snFaKAnMdnvK          81       0.03190         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78       0.27300         0.713
# 4  48UPSzbZjgc449aqz8bxox          82       0.00210         0.592
# 8  33iv3wnGMrrDugd7GBso1z          72       0.00129         0.494
#
#    duration_ms  energy  instrumentalness  ...  mode  speechiness    tempo  \
# 0       214400   0.675          0.000717  ...     0       0.0953   92.909
# 2       200373   0.861          0.000000  ...     1       0.0323  104.034
# 3       271333   0.678          0.000000  ...     0       0.1020  138.009
# 4       329733   0.767          0.001650  ...     0       0.0270   96.483
# 8       169027   0.946          0.000000  ...     1       0.0637  103.408
#
#    time_signature  valence   Genres         subgenres  popularity_artist  \
# 0               4    0.590  hip hop       atl hip hop                 73
# 2               4    0.780     rock  alternative rock                 71
# 3               4    0.734      pop         dance pop                 76
# 4               4    0.328     rock  alternative rock                 86
# 8               4    0.741     rock  alternative rock                 60
#
#                                               genres  \
# 0  [atl hip hop, dance pop, girl group, hip hop, ...
# 2          [alternative rock, pop rock, post-grunge]
# 3  [dance pop, girl group, hip pop, pop, pop rap,...
# 4  [alternative rock, funk metal, funk rock, perm...
# 8  [alternative rock, pop rock, post-grunge, soca...
#
#                                  SongID
# 0                          No ScrubsTLC
# 2                   All StarSmash Mouth
# 3            Say My NameDestiny's Child
# 4  CalifornicationRed Hot Chili Peppers
# 8                 My Own Worst EnemyLit
#
# [5 rows x 23 columns]

# %%
twok.drop(drop_df.index, inplace = True)

# %%
twok.shape
# Out:
# (48454, 23)

# %%
twok['billboard'] = 0

# %%
twok['Peak Position'] = 0

# %%
twok['Weeks on Chart'] = 0

# %%
twok.head()
# Out:
#    artist_name release_date            track_name                track_id  \
# 1    blink-182   1999-06-01  All The Small Things  2m1hi0nfMR9vdGC8UcrnwU
# 5    blink-182   1999-06-01  What's My Age Again?  4LJhJ6DQS7NwE7UKtvcM52
# 6      Dr. Dre   1999-11-16      Forgot About Dre  7iXF2W9vKmDoGAhlHdpyIa
# 7      Dr. Dre   1999-11-16          Still D.R.E.  503OTo2dSqe7qk76rgsbep
# 11     Dr. Dre   1999-11-16      The Next Episode  4LwU4Vp6od3Sb08CsP99GC
#
#     popularity  acousticness  danceability  duration_ms  energy  \
# 1           80        0.0103         0.434       167067   0.897
# 5           77        0.0126         0.391       148360   0.951
# 6           72        0.0879         0.937       222293   0.731
# 7           76        0.1770         0.821       270587   0.774
# 11          71        0.0279         0.916       161507   0.906
#
#     instrumentalness  ...  time_signature  valence  Genres  subgenres  \
# 1           0.000000  ...               4    0.684    rock   pop punk
# 5           0.000378  ...               4    0.468    rock   pop punk
# 6           0.000000  ...               4    0.626     rap     g funk
# 7           0.000676  ...               4    0.547     rap     g funk
# 11          0.000000  ...               4    0.291     rap     g funk
#
#     popularity_artist                                             genres  \
# 1                  83                   [pop punk, punk, socal pop punk]
# 5                  83                   [pop punk, punk, socal pop punk]
# 6                  81  [g funk, gangster rap, hip hop, rap, west coas...
# 7                  81  [g funk, gangster rap, hip hop, rap, west coas...
# 11                 81  [g funk, gangster rap, hip hop, rap, west coas...
#
#                            SongID  billboard Peak Position Weeks on Chart
# 1   All The Small Thingsblink-182          0             0              0
# 5   What's My Age Again?blink-182          0             0              0
# 6         Forgot About DreDr. Dre          0             0              0
# 7             Still D.R.E.Dr. Dre          0             0              0
# 11        The Next EpisodeDr. Dre          0             0              0
#
# [5 rows x 26 columns]

# %%
df_cols = df.columns
twok_cols = twok.columns

inter_columns = df_cols.intersection(twok_cols)
diff_columns = df_cols.difference(twok_cols)

# %%
diff_columns
# Out:
# Index([], dtype='object')

# %%
inter_columns
# Out:
# Index(['SongID', 'track_id', 'genres', 'duration_ms', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'Peak Position', 'Weeks on Chart', 'track_name',
#        'artist_name', 'billboard'],
#       dtype='object')

# %%
twok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48454 entries, 1 to 201706
# Data columns (total 26 columns):
# artist_name          48454 non-null object
# release_date         48454 non-null object
# track_name           48454 non-null object
# track_id             48454 non-null object
# popularity           48454 non-null int64
# acousticness         48454 non-null float64
# danceability         48454 non-null float64
# duration_ms          48454 non-null int64
# energy               48454 non-null float64
# instrumentalness     48454 non-null float64
# key                  48454 non-null int64
# liveness             48454 non-null float64
# loudness             48454 non-null float64
# mode                 48454 non-null int64
# speechiness          48454 non-null float64
# tempo                48454 non-null float64
# time_signature       48454 non-null int64
# valence              48454 non-null float64
# Genres               45090 non-null object
# subgenres            45090 non-null object
# popularity_artist    48454 non-null int64
# genres               48454 non-null object
# SongID               48454 non-null object
# billboard            48454 non-null int64
# Peak Position        48454 non-null int64
# Weeks on Chart       48454 non-null int64
# dtypes: float64(9), int64(9), object(8)
# memory usage: 10.0+ MB

# %%
df.rename(columns={'spotify_track_id':'track_id', 'artist_genre':'genres', 'spotify_track_duration_ms':'duration_ms', 
                   'spotify_track_popularity':'popularity', 'Song': 'track_name','Performer':'artist_name'}, inplace=True)

# %%
twok.drop(['release_date','Genres','subgenres','popularity_artist'], axis=1, inplace=True)

# %%
twok.shape
# Out:
# (48454, 22)

# %%
df.shape
# Out:
# (21732, 22)

# %%
df.columns = map(str.lower, df.columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21732 entries, 0 to 315677
# Data columns (total 22 columns):
# songid              21732 non-null object
# track_id            21732 non-null object
# genres              21732 non-null object
# duration_ms         21732 non-null float64
# popularity          21732 non-null float64
# danceability        21732 non-null float64
# energy              21732 non-null float64
# key                 21732 non-null float64
# loudness            21732 non-null float64
# mode                21732 non-null float64
# speechiness         21732 non-null float64
# acousticness        21732 non-null float64
# instrumentalness    21732 non-null float64
# liveness            21732 non-null float64
# valence             21732 non-null float64
# tempo               21732 non-null float64
# time_signature      21732 non-null float64
# peak position       21732 non-null int64
# weeks on chart      21732 non-null int64
# track_name          21732 non-null object
# artist_name         21732 non-null object
# billboard           21732 non-null int64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 3.8+ MB

# %%
twok.columns = map(str.lower, twok.columns)

# %%
twok.drop_duplicates('songid', keep='first', inplace=True)

# %%
twok.shape
# Out:
# (47635, 22)

# %%
sample_df = twok.sample(n=21732)

# %%
sample_df.head()
# Out:
#           artist_name                track_name                track_id  \
# 20839   Stereophonics     Handbags And Gladrags  3U8UHbqKeR0jlkg8Qlwunr
# 158052   Tony Bennett             Body And Soul  12TAfwmQSufwlerS9UJaQB
# 135658         Attila         Middle Fingers Up  14ZX4MpuG9XW1MaZY5drY0
# 39123      Atmosphere  Trying To Find A Balance  0eE58rFwPTkITwhfXLZ3vb
# 160052   Juan Gabriel      Yo No Sé Que Me Pasó  29xoMLuawmGfjSPxRHij07
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 20839           64      0.028600         0.328       277387   0.726
# 158052          55      0.853000         0.322       203547   0.259
# 135658          52      0.000593         0.596       157053   0.934
# 39123           54      0.058500         0.453       257320   0.831
# 160052          56      0.335000         0.564       282147   0.576
#
#         instrumentalness  key  ...  mode  speechiness    tempo  \
# 20839           0.000643    3  ...     1       0.0312  134.639
# 158052          0.000056    1  ...     1       0.0301   94.721
# 135658          0.059500    1  ...     1       0.0403  114.986
# 39123           0.000000    7  ...     0       0.1170   83.911
# 160052          0.000057    1  ...     0       0.0266  110.362
#
#         time_signature  valence  \
# 20839                4    0.210
# 158052               3    0.222
# 135658               4    0.429
# 39123                4    0.318
# 160052               4    0.236
#
#                                                    genres  \
# 20839   [britpop, modern rock, neo mellow, pop rock, r...
# 158052                           [british soul, neo soul]
# 135658  [deathcore, melodic metalcore, metalcore, nu-m...
# 39123   [alternative hip hop, conscious hip hop, minne...
# 160052                        [grupera, latin, latin pop]
#
#                                     songid billboard peak position  \
# 20839   Handbags And GladragsStereophonics         0             0
# 158052           Body And SoulTony Bennett         0             0
# 135658             Middle Fingers UpAttila         0             0
# 39123   Trying To Find A BalanceAtmosphere         0             0
# 160052    Yo No Sé Que Me PasóJuan Gabriel         0             0
#
#         weeks on chart
# 20839                0
# 158052               0
# 135658               0
# 39123                0
# 160052               0
#
# [5 rows x 22 columns]

# %%
df2 = pd.concat([df,sample_df], ignore_index=True, sort=True)

# %%
df2.tail()
# Out:
#        acousticness                             artist_name  billboard  \
# 43459        0.0799                              Ed Sheeran          0
# 43460        0.3620                           Fifth Harmony          0
# 43461        0.2040                            Mary Lambert          0
# 43462        0.2980                                    U137          0
# 43463        0.7380  Los Plebes del Rancho de Ariel Camacho          0
#
#        danceability  duration_ms  energy  \
# 43459         0.675     163049.0   0.919
# 43460         0.592     217107.0   0.681
# 43461         0.568     231520.0   0.514
# 43462         0.407     307263.0   0.411
# 43463         0.669     163248.0   0.466
#
#                                                   genres  instrumentalness  \
# 43459                                      [pop, uk pop]          0.000000
# 43460  [dance pop, girl group, pop, post-teen pop, ta...          0.000000
# 43461                                                 []          0.000012
# 43462   [compositional ambient, focus, nordic post-rock]          0.935000
# 43463    [banda, regional mexican, regional mexican pop]          0.000000
#
#         key  liveness  ...  peak position  popularity  \
# 43459   8.0    0.1430  ...              0        70.0
# 43460   0.0    0.1420  ...              0        60.0
# 43461   1.0    0.1040  ...              0        54.0
# 43462  11.0    0.0956  ...              0        55.0
# 43463   9.0    0.1100  ...              0        53.0
#
#                                                   songid  speechiness  \
# 43459  Beautiful People (feat. Khalid) - Jack Wins Re...       0.1270
# 43460                          He Like ThatFifth Harmony       0.1410
# 43461                      She Keeps Me WarmMary Lambert       0.0366
# 43462                             Watching the StormU137       0.0347
# 43463  Cuanto Te QuieroLos Plebes del Rancho de Ariel...       0.0298
#
#          tempo  time_signature                track_id  \
# 43459  124.982             4.0  7fvUMiyapMsRRxr07cU8Ef
# 43460  147.016             4.0  1zjcIIrm2fbVFmG3dsj03e
# 43461  144.468             4.0  4Yb6G9OWgGBmfOpxcFxp6P
# 43462  100.010             4.0  5Ormcdpk9HXgPyTmEH8LQ1
# 43463  139.982             3.0  5bbbjsKXBDfI51hYjGX5Yi
#
#                                               track_name valence  \
# 43459  Beautiful People (feat. Khalid) - Jack Wins Remix  0.5850
# 43460                                       He Like That  0.4910
# 43461                                  She Keeps Me Warm  0.3350
# 43462                                 Watching the Storm  0.0723
# 43463                                   Cuanto Te Quiero  0.7400
#
#       weeks on chart
# 43459              0
# 43460              0
# 43461              0
# 43462              0
# 43463              0
#
# [5 rows x 22 columns]

# %%
df2.to_csv('class_tracks.csv')

# %%
df2= pd.read_csv('class_tracks.csv')

# %%
df2.billboard.value_counts()
# Out:
# 1    21732
# 0    21732
# Name: billboard, dtype: int64

# %%
df2[df2.duplicated('songid', keep=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, acousticness, artist_name, billboard, danceability, duration_ms, energy, genres, instrumentalness, key, liveness, loudness, mode, peak position, popularity, songid, speechiness, tempo, time_signature, track_id, track_name, valence, weeks on chart]
# Index: []
#
# [0 rows x 23 columns]

# %%
df2[df2['songid']=='Fuerte No SoyIntocable']
# Out:
#        acousticness artist_name  billboard  danceability  duration_ms  energy  \
# 21884         0.150   Intocable          0         0.660     267533.0   0.441
# 28378         0.117   Intocable          0         0.659     267333.0   0.433
#
#                                                   genres  instrumentalness  \
# 21884  [banda, grupera, latin, latin pop, norteno, ra...          0.000267
# 28378  [banda, grupera, latin, latin pop, norteno, ra...          0.000427
#
#         key  liveness  ...  peak position  popularity                  songid  \
# 21884  11.0    0.0808  ...              0        60.0  Fuerte No SoyIntocable
# 28378  11.0    0.0829  ...              0        68.0  Fuerte No SoyIntocable
#
#        speechiness    tempo  time_signature                track_id  \
# 21884       0.0364  125.666             4.0  4sZ7ET95FXAwUITNwh60bj
# 28378       0.0362  125.556             4.0  7A07Yu1dRND3RKDzbhKrDs
#
#           track_name valence weeks on chart
# 21884  Fuerte No Soy   0.449              0
# 28378  Fuerte No Soy   0.455              0
#
# [2 rows x 22 columns]

# %%
df2.duplicated('artist_name').sum()
# Out:
# 30372

# %%
df2.tail()
# Out:
#        acousticness                             artist_name  billboard  \
# 43459        0.0799                              Ed Sheeran          0
# 43460        0.3620                           Fifth Harmony          0
# 43461        0.2040                            Mary Lambert          0
# 43462        0.2980                                    U137          0
# 43463        0.7380  Los Plebes del Rancho de Ariel Camacho          0
#
#        danceability  duration_ms  energy  \
# 43459         0.675     163049.0   0.919
# 43460         0.592     217107.0   0.681
# 43461         0.568     231520.0   0.514
# 43462         0.407     307263.0   0.411
# 43463         0.669     163248.0   0.466
#
#                                                   genres  instrumentalness  \
# 43459                                      [pop, uk pop]          0.000000
# 43460  [dance pop, girl group, pop, post-teen pop, ta...          0.000000
# 43461                                                 []          0.000012
# 43462   [compositional ambient, focus, nordic post-rock]          0.935000
# 43463    [banda, regional mexican, regional mexican pop]          0.000000
#
#         key  liveness  ...  peak position  popularity  \
# 43459   8.0    0.1430  ...              0        70.0
# 43460   0.0    0.1420  ...              0        60.0
# 43461   1.0    0.1040  ...              0        54.0
# 43462  11.0    0.0956  ...              0        55.0
# 43463   9.0    0.1100  ...              0        53.0
#
#                                                   songid  speechiness  \
# 43459  Beautiful People (feat. Khalid) - Jack Wins Re...       0.1270
# 43460                          He Like ThatFifth Harmony       0.1410
# 43461                      She Keeps Me WarmMary Lambert       0.0366
# 43462                             Watching the StormU137       0.0347
# 43463  Cuanto Te QuieroLos Plebes del Rancho de Ariel...       0.0298
#
#          tempo  time_signature                track_id  \
# 43459  124.982             4.0  7fvUMiyapMsRRxr07cU8Ef
# 43460  147.016             4.0  1zjcIIrm2fbVFmG3dsj03e
# 43461  144.468             4.0  4Yb6G9OWgGBmfOpxcFxp6P
# 43462  100.010             4.0  5Ormcdpk9HXgPyTmEH8LQ1
# 43463  139.982             3.0  5bbbjsKXBDfI51hYjGX5Yi
#
#                                               track_name valence  \
# 43459  Beautiful People (feat. Khalid) - Jack Wins Remix  0.5850
# 43460                                       He Like That  0.4910
# 43461                                  She Keeps Me Warm  0.3350
# 43462                                 Watching the Storm  0.0723
# 43463                                   Cuanto Te Quiero  0.7400
#
#       weeks on chart
# 43459              0
# 43460              0
# 43461              0
# 43462              0
# 43463              0
#
# [5 rows x 22 columns]

# %%
df2[(df2['artist_name']=='Drake') & (df2['billboard']==1)]
# Out:
#        acousticness artist_name  billboard  danceability  duration_ms  energy  \
# 1221        0.73600       Drake          1         0.519     305373.0   0.576
# 1293        0.00302       Drake          1         0.903     267066.0   0.621
# 1365        0.13700       Drake          1         0.400     328906.0   0.574
# 2264        0.02400       Drake          1         0.715     241853.0   0.561
# 2877        0.53500       Drake          1         0.827     310933.0   0.477
# ...             ...         ...        ...           ...          ...     ...
# 19444       0.35200       Drake          1         0.440     297373.0   0.421
# 19646       0.06180       Drake          1         0.589     311960.0   0.869
# 19855       0.01250       Drake          1         0.831     224013.0   0.651
# 20725       0.15800       Drake          1         0.779     270186.0   0.799
# 21213       0.08190       Drake          1         0.613     253533.0   0.738
#
#                                                   genres  instrumentalness  \
# 1221   ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 1293   ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000186
# 1365   ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 2264   ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 2877   ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# ...                                                  ...               ...
# 19444  ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000013
# 19646  ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 19855  ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 20725  ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
# 21213  ['canadian hip hop', 'canadian pop', 'hip hop'...          0.000000
#
#        key  liveness  ...  peak position  popularity  \
# 1221   4.0    0.3710  ...             64        60.0
# 1293   2.0    0.0504  ...              2        77.0
# 1365   9.0    0.3810  ...             68        59.0
# 2264   1.0    0.0769  ...             52        71.0
# 2877   7.0    0.1360  ...             81        63.0
# ...    ...       ...  ...            ...         ...
# 19444  6.0    0.1360  ...             44        62.0
# 19646  5.0    0.2390  ...             86        59.0
# 19855  1.0    0.0809  ...             51        58.0
# 20725  9.0    0.2090  ...             89        60.0
# 21213  6.0    0.3200  ...             54        61.0
#
#                            songid  speechiness    tempo  time_signature  \
# 1221                Lose YouDrake       0.4140   87.983             4.0
# 1293           Hotline BlingDrake       0.0578  134.969             4.0
# 1365   Keep The Family CloseDrake       0.0494  128.584             4.0
# 2264                  LegendDrake       0.0721  100.076             4.0
# 2877              No Tellin'Drake       0.2750   95.030             4.0
# ...                           ...          ...      ...             ...
# 19444             U With Me?Drake       0.1540   87.629             4.0
# 19646                  ViewsDrake       0.3110   80.007             4.0
# 19855           The LanguageDrake       0.4370  120.064             4.0
# 20725         Worst BehaviorDrake       0.1500  109.944             4.0
# 21213      Weston Road FlowsDrake       0.3110   82.833             4.0
#
#                      track_id             track_name valence weeks on chart
# 1221   2Na0z2gfN67Rzf0vp74Wi3               Lose You  0.3730              1
# 1293   0wwPcA6wtMf6HUMpIRdeP7          Hotline Bling  0.5530             36
# 1365   7sBwAWyXfiIgrYQ8BaJESH  Keep The Family Close  0.1990              2
# 2264   1ID1QFSNNxi0hiZCNcwjUC                 Legend  0.2970             12
# 2877   2durxb17bXcmQJHSt8JAdO             No Tellin'  0.5580              2
# ...                       ...                    ...     ...            ...
# 19444  03L2AoiRbWhvt7BDMx1jUB             U With Me?  0.1160              4
# 19646  7MjSipTto9QljYzZnloXOn                  Views  0.0737              1
# 19855  3IQgeOgdHIag6mu0mgKRgQ           The Language  0.5020             20
# 20725  48RN2EOOyG2Gs5Pyla7ZJj         Worst Behavior  0.4140             11
# 21213  4PA16FAl8LPmFmOhARawdV      Weston Road Flows  0.3410              2
#
# [75 rows x 22 columns]

# %%
df2.artist_name.value_counts()
# Out:
# Glee Cast                              216
# Drake                                  122
# Eminem                                  90
# Taylor Swift                            86
# The Beatles                             76
#                                       ...
# Chris Brown Featuring Justin Bieber      1
# Wilder Woods                             1
# Outside HD Samples                       1
# El Kuelgue                               1
# Karina                                   1
# Name: artist_name, Length: 13092, dtype: int64

# %%
df3 = pd.get_dummies(df2.artist_name, drop_first= True)

# %%
df3.shape
# Out:
# (43464, 13091)

# %%
df2 = df2.merge(df3, left_index=True, right_index=True)

# %%
df2.drop('Unnamed: 0', axis=1, inplace = True)

# %%
y = df2['billboard']
X = df2.drop(['track_name','artist_name','track_id', 'genres','billboard','songid', 'weeks on chart', 'peak position',], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
tree_clf = DecisionTreeClassifier(max_depth = 10, min_samples_leaf = 10)
tree_clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=10, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "decision_trees"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

export_graphviz(
        tree_clf,
        out_file = os.path.join(IMAGES_PATH, "tracks.dot"),
        feature_names = X.columns,
        class_names = np.unique(y).astype('str'),
        rounded = True,
        filled = True)

Source.from_file(os.path.join(IMAGES_PATH, "tracks.dot"))

# %%
tree_clf.predict(X_test)
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
tree_clf.score(X_test, y_test)
# Out:
# 0.8211853487944045

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth' : [i for i in range(5,15)], 
             'min_samples_leaf' : [i for i in range(10,100)]
             }

opt_model = GridSearchCV(tree_clf, param_grid, cv=10, scoring='roc_auc',
                        n_jobs=1, return_train_score=True)
opt_model.fit(X_train, y_train)
best_model = opt_model.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-cca5bebab977> in <module>
#       7 opt_model = GridSearchCV(tree_clf, param_grid, cv=10, scoring='roc_auc',
#       8                         n_jobs=1, return_train_score=True)
# ----> 9 opt_model.fit(X_train, y_train)
#      10 best_model = opt_model.best_estimator_
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#     922                 self._iterating = self._original_iterator is not None
#     923
# --> 924             while self.dispatch_one_batch(iterator):
#     925                 pass
#     926
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
#     132             if issparse(X):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      47     # safely to reduce dtype induced overflows.
#      48     is_float = X.dtype.kind in 'fc'
# ---> 49     if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
#      50         pass
#      51     elif is_float:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in _safe_accumulator_op(op, x, *args, **kwargs)
#     684     """
#     685     if np.issubdtype(x.dtype, np.floating) and x.dtype.itemsize < 8:
# --> 686         result = op(x, *args, **kwargs, dtype=np.float64)
#     687     else:
#     688         result = op(x, *args, **kwargs)
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2180
#    2181     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2182                           initial=initial, where=where)
#    2183
#    2184
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# KeyboardInterrupt:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21732 entries, 0 to 315677
# Data columns (total 22 columns):
# songid              21732 non-null object
# track_id            21732 non-null object
# genres              21732 non-null object
# duration_ms         21732 non-null float64
# popularity          21732 non-null float64
# danceability        21732 non-null float64
# energy              21732 non-null float64
# key                 21732 non-null float64
# loudness            21732 non-null float64
# mode                21732 non-null float64
# speechiness         21732 non-null float64
# acousticness        21732 non-null float64
# instrumentalness    21732 non-null float64
# liveness            21732 non-null float64
# valence             21732 non-null float64
# tempo               21732 non-null float64
# time_signature      21732 non-null float64
# peak position       21732 non-null int64
# weeks on chart      21732 non-null int64
# track_name          21732 non-null object
# artist_name         21732 non-null object
# billboard           21732 non-null int64
# dtypes: float64(14), int64(3), object(5)
# memory usage: 3.8+ MB

# %%
numeric_features = ['duration_ms', 'tempo', 'loudness', 'popularity']
numeric_transformer = Pipeline(steps=[('scaler', MinMaxScaler())])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features)])

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression(solver='lbfgs'))])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('num',
#                                                   Pipeline(memory=None,
#                                                            steps=[('scaler',
#                                                                    MinMaxScaler(copy=True,
#                                                                                 feature_range=(0,
#                                                                                                1)))],
#                                                            verbose=False),
#                                                   ['duration_ms', 'tempo',
#                                                    'loudness', 'popularity'])],
#                                    verbose=False)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='warn', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
clf.predict(X_test)
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
clf.score(X_test, y_test)
# Out:
# 0.7581446714522363

# %%
polynomial_svm_clf = Pipeline([
    ('poly_features', PolynomialFeatures(degree=2)),
    ('preprocessor', preprocessor),
    ('svm_clf', LinearSVC(C = 10, loss='hinge'))
])

polynomial_svm_clf.fit(X_train,y_train)
